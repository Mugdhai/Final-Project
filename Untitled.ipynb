# %%
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
eye_cascade=cv2.CascadeClassifier('D:\project code\sports_person_classifier\model\opencv\haarcascade_eye.xml')
face_cascade=cv2.CascadeClassifier('D:\project code\sports_person_classifier\model\opencv\haarcascade_frontalface_default.xml')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to read image at {image_path}")
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        roi_gray = gray[y:y + h, x:x + w]
        roi_color = img[y:y + h, x:x + w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color
    return None  # Return None if no suitable face is found

# %%
path_to_data="D:\project code\sports_person_classifier\model\dataset"
path_to_cr_data='D:\project code\sports_person_classifier\model\dataset\cropped'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['D:\\project code\\sports_person_classifier\\model\\dataset\\cropped',
#  'D:\\project code\\sports_person_classifier\\model\\dataset\\Hema Das',
#  'D:\\project code\\sports_person_classifier\\model\\dataset\\mary com',
#  'D:\\project code\\sports_person_classifier\\model\\dataset\\mitali raj',
#  'D:\\project code\\sports_person_classifier\\model\\dataset\\pv sindhu',
#  'D:\\project code\\sports_person_classifier\\model\\dataset\\saina nehwal']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
for img_dir in img_dirs:
    celebrity_name=img_dir.split('\\')[-1]
    print(celebrity_name)
# Out:
# cropped
# Hema Das
# mary com
# mitali raj
# pv sindhu
# saina nehwal

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1].strip()  # Remove leading/trailing whitespaces
    print(celebrity_name)

    # Initialize an empty list for each celebrity
    celebrity_file_names_dict[celebrity_name] = []

    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = os.path.join(path_to_cr_data, celebrity_name)
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                print(cropped_folder)

            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = os.path.join(cropped_folder, cropped_file_name)

            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# Hema Das
# D:\project code\sports_person_classifier\model\dataset\cropped\Hema Das
# mary com
# D:\project code\sports_person_classifier\model\dataset\cropped\mary com
# mitali raj
# D:\project code\sports_person_classifier\model\dataset\cropped\mitali raj
# pv sindhu
# D:\project code\sports_person_classifier\model\dataset\cropped\pv sindhu
# saina nehwal
# D:\project code\sports_person_classifier\model\dataset\cropped\saina nehwal

# %%
celebrity_file_names_dict
# Out:
# {'cropped': [],
#  'Hema Das': ['D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das1.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das2.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das3.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das4.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das5.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das6.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das7.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das8.png',
#   'D:\\project code\\sports_person_classifier\\model\\dataset\\cropped\\Hema Das\\Hema Das9.png',
# ...

# %% [markdown]
#  Preprocessing: Use wavelet transform as a feature for traning our model
# In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %%
import numpy as np
import pywt
import cv2   

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
file_path = r'D:\project code\sports_person_classifier\model\test images\s2.jpg'

cropped_img = cv2.imread(file_path)


if cropped_img is not None:
    # Display the image shape
    print('Image shape:', cropped_img.shape)
    
else:
    print('Error: Image not loaded.')
# Out:
# Image shape: (612, 408, 3)

# %%
plt.imshow(cropped_img)

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'cropped': 0,
#  'Hema Das': 1,
#  'mary com': 2,
#  'mitali raj': 3,
#  'pv sindhu': 4,
#  'saina nehwal': 5}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[222],
#        [162],
#        [ 19],
#        ...,
#        [  7],
#        [  9],
#        [ 26]], dtype=uint8)

# %%
y[0]
# Out:
# 1

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (80, 4096)

# %% [markdown]
# Data cleaning process is done. Now we are ready to train our model

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.9

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      1.00      0.86         3
#            2       0.67      1.00      0.80         2
#            3       1.00      1.00      1.00        10
#            4       1.00      0.50      0.67         2
#            5       1.00      0.67      0.80         3
#
#     accuracy                           0.90        20
#    macro avg       0.88      0.83      0.82        20
# weighted avg       0.93      0.90      0.90        20

# %% [markdown]
# Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\python3.10.2\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\python3.10.2\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\python3.10.2\lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.866667
# 1        random_forest    0.883333
# 2  logistic_regression    0.816667
#
#                                     best_params
# 0           {'svc__C': 1, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=1, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.85

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.85

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.85

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 3,  0,  0,  0,  0],
#        [ 0,  2,  0,  0,  0],
#        [ 0,  0, 10,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 1,  0,  0,  0,  2]], dtype=int64)

# %%
class_dict
# Out:
# {'cropped': 0,
#  'Hema Das': 1,
#  'mary com': 2,
#  'mitali raj': 3,
#  'pv sindhu': 4,
#  'saina nehwal': 5}

# %% [markdown]
# Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ['saved_model.pkl']

# %% [markdown]
# Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
